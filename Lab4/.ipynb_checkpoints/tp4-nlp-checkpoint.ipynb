# %% [markdown]
# # Libraries

# %%
from datasets import load_dataset
import pandas as pd
import numpy as np
import os
from nltk.corpus import stopwords
import nltk
import string
from torch.nn.utils.rnn import pad_sequence
import torch
from torch.utils.data import DataLoader, Dataset
from torch.optim import Adam
from torch.nn import CrossEntropyLoss
from tqdm.notebook import tqdm
from torchmetrics.classification import MulticlassAccuracy, MulticlassF1Score

# %%
dataset = load_dataset("conll2003",trust_remote_code=True)
# Out:
# README.md:   0%|          | 0.00/12.3k [00:00<?, ?B/s]
# conll2003.py:   0%|          | 0.00/9.57k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/983k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/14041 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/3250 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/3453 [00:00<?, ? examples/s]

# %%
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
lemmatizer = nltk.WordNetLemmatizer()

# %%
def preprocess_text(text):
    text = text.lower()
    text = lemmatizer.lemmatize(text)

    return text

# %%
def preprocess_dataset(dataset):
    
    processed_dataset = []

    for row in dataset:
        
        row["tokens"] = list(map(preprocess_text, row["tokens"]))
        row["tokens"] = list(filter(lambda x: x not in string.punctuation, row["tokens"]))
        row.pop("id")
        row.pop("pos_tags")
        row.pop("chunk_tags")

        processed_dataset.append(row)

    return processed_dataset

# %%
train = preprocess_dataset(dataset["train"])
validation = preprocess_dataset(dataset["validation"])
test = preprocess_dataset(dataset["test"])

# %%
ner_tags = dataset["train"].features["ner_tags"].feature.names
#map to dictionary
ner_tags = {ner_tags[i]: i for i in range(len(ner_tags))}
print(ner_tags)
# Out:
# {'O': 0, 'B-PER': 1, 'I-PER': 2, 'B-ORG': 3, 'I-ORG': 4, 'B-LOC': 5, 'I-LOC': 6, 'B-MISC': 7, 'I-MISC': 8}

# %%
MAX_LEN = 113

# %%
#getting the unique words in the dataset for vocab
vocab = {
    '<PAD>': 0,
    '<UNK>': 1
}
i = 2
for row in train:
    for word in row["tokens"]:
        if word not in vocab:
            vocab[word] = i
            i += 1

# %%
len(vocab)
# Out:
# 19601

# %%
emb = [
    [0.15,0.2],
    [0.1,0.25],
    [0.5,0.32],
]

seq = [0,0,1,2]

seq = [
    [0.15,0.2],
    [0.15,0.2],
    [0.1,0.25],
    [0.5,0.32],
]

# %%
#replace words with their index in the vocab
def word_to_idx(word):
    if word in vocab:
        return vocab[word]
    else:
        return vocab["<UNK>"]
    
def index(dataset):

    indexed_dataset = []

    for row in dataset:
        row["tokens"] = list(map(word_to_idx, row["tokens"]))       
        indexed_dataset.append(row)

    return indexed_dataset

# %%
train = index(train)
validation = index(validation)
test = index(test)

# %%
NUM_CLASSES = len(dataset['train'].features['ner_tags'].feature.names)
print(NUM_CLASSES)
# Out:
# 9

# %%
def pad_to_max_length(dataset):

    for row in dataset:
        if len(row["tokens"]) < MAX_LEN:
            row["tokens"] = row["tokens"] + [vocab['<PAD>']] * (MAX_LEN - len(row["tokens"]))
            row["ner_tags"] = row["ner_tags"] + [NUM_CLASSES] * (MAX_LEN - len(row["ner_tags"]))
        else:
            row["tokens"] = row["tokens"][:MAX_LEN]
            row["ner_tags"] = row["ner_tags"][:MAX_LEN]

    return dataset

# %%
#apply padding
train = pad_to_max_length(train)
validation = pad_to_max_length(validation)
test = pad_to_max_length(test)

# %%
def collate_fn(batch):
    tokens = torch.stack([torch.tensor(row["tokens"]) for row in batch])
    ner_tags = torch.stack([torch.tensor(row["ner_tags"]) for row in batch])

    return tokens, ner_tags

# %%
train_dataloader = DataLoader(train, batch_size=32, shuffle=True, collate_fn=collate_fn)
validation_dataloader = DataLoader(validation, batch_size=32, shuffle=True, collate_fn=collate_fn)
test_dataloader = DataLoader(test, batch_size=32, shuffle=True, collate_fn=collate_fn)

# %%
#define gru model
class GRUModel(torch.nn.Module):
    def __init__(self, vocab_size, num_classes):
        super(GRUModel, self).__init__()
        
        self.embedding = torch.nn.Embedding(vocab_size, 128)
        self.gru = torch.nn.GRU(128, 128, batch_first=True, bidirectional=True)
        self.fc = torch.nn.Linear(256, num_classes)
        
    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.gru(x)
        x = self.fc(x)
        
        return x

# %%
EPOCHS = 100
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
model = GRUModel(len(vocab), NUM_CLASSES+1).to(DEVICE)
optimizer = Adam(model.parameters(), lr=0.0005)
criterion = CrossEntropyLoss()
acc = MulticlassAccuracy(NUM_CLASSES+1).to(DEVICE)
f1 = MulticlassF1Score(NUM_CLASSES+1, average='macro').to(DEVICE)

history = {'train': {'loss': [], 'acc': [], 'f1': []},
           'val': {'loss': [], 'acc': [], 'f1': []}}

for epoch in range(EPOCHS):
    running_loss = 0.0
    running_acc = 0.0
    running_f1 = 0.0
    val_loss = 0.0
    val_acc = 0.0
    val_f1 = 0.0

    model.train()
    t = tqdm(train_dataloader)
    for i, (tokens, ner_tags) in enumerate(t):
        tokens, ner_tags = tokens.to(DEVICE), ner_tags.to(DEVICE)
        optimizer.zero_grad()
        output = model(tokens)

        # Calculate loss, accuracy, and F1 score
        loss = criterion(output.view(-1, NUM_CLASSES+1), ner_tags.view(-1))
        acc_score = acc(output.view(-1, NUM_CLASSES+1), ner_tags.view(-1))
        f1_score = f1(output.view(-1, NUM_CLASSES+1), ner_tags.view(-1))

        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        running_acc += acc_score.item()
        running_f1 += f1_score.item()

    model.eval()
    with torch.no_grad():
        for tokens, ner_tags in validation_dataloader:
            tokens, ner_tags = tokens.to(DEVICE), ner_tags.to(DEVICE)
            output = model(tokens)

            loss = criterion(output.view(-1, NUM_CLASSES+1), ner_tags.view(-1))
            acc_score = acc(output.view(-1, NUM_CLASSES+1), ner_tags.view(-1))
            f1_score = f1(output.view(-1, NUM_CLASSES+1), ner_tags.view(-1))

            val_loss += loss.item()
            val_acc += acc_score.item()
            val_f1 += f1_score.item()

    # Calculate average loss, accuracy, and F1 score for the epoch
    train_loss = running_loss / len(train_dataloader)
    train_acc = running_acc / len(train_dataloader)
    train_f1 = running_f1 / len(train_dataloader)

    val_loss = val_loss / len(validation_dataloader)
    val_acc = val_acc / len(validation_dataloader)
    val_f1 = val_f1 / len(validation_dataloader)

    # Store the metrics in the history dictionary
    history['train']['loss'].append(train_loss)
    history['train']['acc'].append(train_acc)
    history['train']['f1'].append(train_f1)
    history['val']['loss'].append(val_loss)
    history['val']['acc'].append(val_acc)
    history['val']['f1'].append(val_f1)

    print(f"Epoch {epoch+1}/{EPOCHS}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Train F1: {train_f1:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}, Val F1: {val_f1:.4f}")
# Out:
#   0%|          | 0/439 [00:00<?, ?it/s]
# Epoch
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.plot(history['train']['loss'], label='train')
plt.plot(history['val']['loss'], label='val')
plt.title('Loss')
plt.legend()

#plot the accuracy
plt.subplot(1, 3, 2)
plt.plot(history['train']['acc'], label='train')
plt.plot(history['val']['acc'], label='val')
plt.title('Accuracy')
plt.legend()

#plot the f1 score
plt.subplot(1, 3, 3)
plt.plot(history['train']['f1'], label='train')
plt.plot(history['val']['f1'], label='val')
plt.title('F1 Score')
plt.legend()

plt.show()

# %%
class ImprovedGRUModel(torch.nn.Module):
    def __init__(self, vocab_size, num_classes, embedding_dim=100, dropout_rate=0.2):
        super(ImprovedGRUModel, self).__init__()
        self.embedding = torch.nn.Embedding(vocab_size, embedding_dim)
        self.dropout = torch.nn.Dropout(dropout_rate)
        self.gru = torch.nn.GRU(embedding_dim, 32, batch_first=True, bidirectional=True)
        self.fc = torch.nn.Linear(64, num_classes)  # 64 = 32*2 (bidirectional)
        
    def forward(self, x):
        x = self.embedding(x)
        x = self.dropout(x)
        x, _ = self.gru(x)
        x = self.fc(x)
        return x

# %%
model = ImprovedGRUModel(
    vocab_size=len(vocab),
    num_classes=NUM_CLASSES+1,
    embedding_dim=100,
    dropout_rate=0.2
).to(DEVICE)

optimizer = Adam(model.parameters(), lr=0.001)  
criterion = CrossEntropyLoss()
acc = MulticlassAccuracy(NUM_CLASSES+1).to(DEVICE)
f1 = MulticlassF1Score(NUM_CLASSES+1, average='macro').to(DEVICE)

history = {'train': {'loss': [], 'acc': [], 'f1': []},
           'val': {'loss': [], 'acc': [], 'f1': []}}

for epoch in range(EPOCHS*2):
    running_loss = 0.0
    running_acc = 0.0
    running_f1 = 0.0
    val_loss = 0.0
    val_acc = 0.0
    val_f1 = 0.0

    model.train()
    t = tqdm(train_dataloader)
    for i, (tokens, ner_tags) in enumerate(t):
        tokens, ner_tags = tokens.to(DEVICE), ner_tags.to(DEVICE)
        optimizer.zero_grad()
        output = model(tokens)

        # Calculate loss, accuracy, and F1 score
        loss = criterion(output.view(-1, NUM_CLASSES+1), ner_tags.view(-1))
        acc_score = acc(output.view(-1, NUM_CLASSES+1), ner_tags.view(-1))
        f1_score = f1(output.view(-1, NUM_CLASSES+1), ner_tags.view(-1))

        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        running_acc += acc_score.item()
        running_f1 += f1_score.item()

    model.eval()
    with torch.no_grad():
        for tokens, ner_tags in validation_dataloader:
            tokens, ner_tags = tokens.to(DEVICE), ner_tags.to(DEVICE)
            output = model(tokens)

            loss = criterion(output.view(-1, NUM_CLASSES+1), ner_tags.view(-1))
            acc_score = acc(output.view(-1, NUM_CLASSES+1), ner_tags.view(-1))
            f1_score = f1(output.view(-1, NUM_CLASSES+1), ner_tags.view(-1))

            val_loss += loss.item()
            val_acc += acc_score.item()
            val_f1 += f1_score.item()

    # Calculate average loss, accuracy, and F1 score for the epoch
    train_loss = running_loss / len(train_dataloader)
    train_acc = running_acc / len(train_dataloader)
    train_f1 = running_f1 / len(train_dataloader)

    val_loss = val_loss / len(validation_dataloader)
    val_acc = val_acc / len(validation_dataloader)
    val_f1 = val_f1 / len(validation_dataloader)

    # Store the metrics in the history dictionary
plt.plot(history['val']['f1'], label='val')
plt.title('F1 Score')
plt.legend()

plt.show()

# %%
#save model
torch.save(model.state_dict(), "improved_gru_ner_model.pth")

# %%
# Evaluate the first model (GRUModel)
model = GRUModel(len(vocab), NUM_CLASSES+1).to(DEVICE)
model.load_state_dict(torch.load("gru_ner_model.pth", weights_only=True))  # Fix warning
model.eval()

test_loss = 0.0
test_acc = 0.0
test_f1 = 0.0

with torch.no_grad():
    for tokens, ner_tags in test_dataloader:
        tokens, ner_tags = tokens.to(DEVICE), ner_tags.to(DEVICE)
        output = model(tokens)

        loss = criterion(output.view(-1, NUM_CLASSES+1), ner_tags.view(-1))
        acc_score = acc(output.view(-1, NUM_CLASSES+1), ner_tags.view(-1))
        f1_score = f1(output.view(-1, NUM_CLASSES+1), ner_tags.view(-1))

        test_loss += loss.item()
        test_acc += acc_score.item()
        test_f1 += f1_score.item()

test_loss /= len(test_dataloader)
test_acc /= len(test_dataloader)
test_f1 /= len(test_dataloader)

print(f"Test Loss (GRUModel): {test_loss:.4f}, Test Acc: {test_acc:.4f}, Test F1: {test_f1:.4f}")

# Evaluate the second model (ImprovedGRUModel)
model = ImprovedGRUModel(len(vocab), NUM_CLASSES+1).to(DEVICE)  # Removed embedding_matrix
model.load_state_dict(torch.load("improved_gru_ner_model.pth", weights_only=True))  # Fix warning & filename
model.eval()

test_loss = 0.0
test_acc = 0.0
test_f1 = 0.0

with torch.no_grad():
    for tokens, ner_tags in test_dataloader:
        tokens, ner_tags = tokens.to(DEVICE), ner_tags.to(DEVICE)
        output = model(tokens)

        loss = criterion(output.view(-1, NUM_CLASSES+1), ner_tags.view(-1))
        acc_score = acc(output.view(-1, NUM_CLASSES+1), ner_tags.view(-1))
        f1_score = f1(output.view(-1, NUM_CLASSES+1), ner_tags.view(-1))

        test_loss += loss.item()
        test_acc += acc_score.item()
        test_f1 += f1_score.item()

test_loss /= len(test_dataloader)
test_acc /= len(test_dataloader)
test_f1 /= len(test_dataloader)

print(f"Test Loss (ImprovedGRUModel): {test_loss:.4f}, Test Acc: {test_acc:.4f}, Test F1: {test_f1:.4f}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_31/847124249.py in <cell line: 0>()
#       9
#      10 with torch.no_grad():
# ---> 11     for tokens, ner_tags in test_dataloader:
#      12         tokens, ner_tags = tokens.to(DEVICE), ner_tags.to(DEVICE)
#      13         output = model(tokens)
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     699                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700                 self._reset()  # type: ignore[call-arg]
# --> 701             data = self._next_data()
#     702             self._num_yielded += 1
#     703             if (
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     755     def _next_data(self):
#     756         index = self._next_index()  # may raise StopIteration
# --> 757         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758         if self._pin_memory:
#     759             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
# ---> 55         return self.collate_fn(data)
#
# /tmp/ipykernel_31/3520271777.py in collate_fn(batch)
#       1 def collate_fn(batch):
#       2     tokens = torch.stack([torch.tensor(row["tokens"]) for row in batch])
# ----> 3     ner_tags = torch.stack([torch.tensor(row["ner_tags"]) for row in batch])
#       4
#       5     return tokens, ner_tags
#
# RuntimeError: stack expects each tensor to be equal size, but got [113] at entry 0 and [124] at entry 13
